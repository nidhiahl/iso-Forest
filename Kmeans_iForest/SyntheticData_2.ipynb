# %% [markdown]
# # Imports

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import multivariate_normal
import random as rn
import seaborn as sb
sb.set_style(style="whitegrid")
sb.set_color_codes()
import scipy.ndimage
from scipy.interpolate import griddata
import numpy.ma as ma
from numpy.random import uniform, seed
from google.colab import files

# %% [markdown]
# Data Generation

# %%
dense1 = np.random.random_sample((9000, 2))
dense1[:, 0] *= 5
dense1[:, 0] += 2.5
dense1[:, 1] *= 15
dense1[:, 1] += 15

dense2 = np.random.random_sample((3000, 2))
dense2[:, 0] *= 5
dense2[:, 0] += 2.5
dense2[:, 1] *= 5
dense2[:, 1] += 2.5

dense3 = np.random.random_sample((27000, 2))
dense3[:, 0] *= 15
dense3[:, 0] += 15
dense3[:, 1] *= 15
dense3[:, 1] += 15

dense4 = np.random.random_sample((9000, 2))
dense4[:, 0] *= 15
dense4[:, 0] += 15
dense4[:, 1] *= 5
dense4[:, 1] += 2.5

sparse1 = np.random.random_sample((37, 2))
sparse1[:, 0] *= 2.5
sparse1[:, 0] += 0
sparse1[:, 1] *= 15
sparse1[:, 1] += 15

sparse2 = np.random.random_sample((13, 2))
sparse2[:, 0] *= 2.5
sparse2[:, 0] += 0
sparse2[:, 1] *= 5
sparse2[:, 1] += 2.5

sparse3 = np.random.random_sample((100, 2))
sparse3[:, 0] *= 5
sparse3[:, 0] += 2.5
sparse3[:, 1] *= 20
sparse3[:, 1] += 30

sparse4 = np.random.random_sample((37, 2))
sparse4[:, 0] *= 5
sparse4[:, 0] += 2.5
sparse4[:, 1] *= 7.5
sparse4[:, 1] += 7.5

sparse5 = np.random.random_sample((13, 2))
sparse5[:, 0] *= 5
sparse5[:, 0] += 2.5
sparse5[:, 1] *= 2.5
sparse5[:, 1] += 0

sparse6 = np.random.random_sample((112, 2))
sparse6[:, 0] *= 7.5
sparse6[:, 0] += 7.5
sparse6[:, 1] *= 15
sparse6[:, 1] += 15

sparse7 = np.random.random_sample((37, 2))
sparse7[:, 0] *= 7.5
sparse7[:, 0] += 7.5
sparse7[:, 1] *= 5
sparse7[:, 1] += 2.5

sparse8 = np.random.random_sample((300, 2))
sparse8[:, 0] *= 15
sparse8[:, 0] += 15
sparse8[:, 1] *= 20
sparse8[:, 1] += 30

sparse9 = np.random.random_sample((112, 2))
sparse9[:, 0] *= 15
sparse9[:, 0] += 15
sparse9[:, 1] *= 7.5
sparse9[:, 1] += 7.5

sparse10 = np.random.random_sample((37, 2))
sparse10[:, 0] *= 15
sparse10[:, 0] += 15
sparse10[:, 1] *= 2.5
sparse10[:, 1] += 0

sparse11 = np.random.random_sample((300, 2))
sparse11[:, 0] *= 20
sparse11[:, 0] += 30
sparse11[:, 1] *= 15
sparse11[:, 1] += 15

sparse12 = np.random.random_sample((100, 2))
sparse12[:, 0] *= 20
sparse12[:, 0] += 30
sparse12[:, 1] *= 5
sparse12[:, 1] += 2.5

data = np.concatenate((dense1, dense2, dense3, dense4, sparse1, sparse2, sparse3, sparse4, sparse5, sparse6,  sparse7,  sparse8,  sparse9,  sparse10, sparse11, sparse12), axis=0)
print(data)
# Out:
# [[ 5.02181311 19.82871086]
#  [ 6.47691685 26.38240364]
#  [ 5.49380798 18.33720774]
#  ...
#  [47.09853388  3.37259042]
#  [35.67052272  6.12525487]
#  [32.09969401  5.24258752]]

# %% [markdown]
# ## Data Visualisation

# %%
fig=plt.figure(figsize=(6,6))
fig.add_subplot(111)
plt.plot(data[:,0],data[:,1],'o', markersize=1, color=[0.5,0.5,0.5])
plt.grid("off")
plt.axis("equal")
plt.xlim([0,50])
plt.ylim([0,50])
plt.tick_params(direction='out', length=6, width=0, colors='k',labelsize=15)
plt.show()

# %% [markdown]
# ## Save to csv

# %%
label=np.zeros(49198, int)

dict={'1':data[:, 0], '2':data[:, 1], 'label':label}
df=pd.DataFrame(dict)

df.to_csv('artificialData.csv', sep='\t')
files.download("artificialData.csv")

# %% [markdown]
# ## Train iForest

# %% [markdown]
# This process is done on local machine.

# %% [markdown]
# ## Obtain Anomaly scores

# %%
files.upload()
files.upload()
# Out:
#      <input type="file" id="files-5ba4d62f-ff17-4e73-8977-239084f5b068" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5ba4d62f-ff17-4e73-8977-239084f5b068">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving artificialData_basic_iForest.csv to artificialData_basic_iForest.csv
#      <input type="file" id="files-0261254b-80f8-4def-bf16-a5ae38dd49c9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0261254b-80f8-4def-bf16-a5ae38dd49c9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving artificialData_kmeans_iForest.csv to artificialData_kmeans_iForest.csv
# {'artificialData_kmeans_iForest.csv': b'pointId Ascore actuallabel\n0 0.52723 0\n1 0.610553 0\n2 0.512437 0\n3 0.627307 0\n4 0.617513 0\n5 0.534113 0\n6 0.576751 0\n7 0.481474 0\n8 0.535388 0\n9 0.621019 0\n10 0.546522 0\n11 0.621172 0\n12 0.503331 0\n13 0.547499 0\n14 0.550247 0\n15 0.621526 0\n16 0.617543 0\n17 0.541175 0\n18 0.625417 0\n19 0.545092 0\n20 0.496933 0\n21 0.525515 0\n22 0.548365 0\n23 0.551392 0\n24 0.559626 0\n25 0.591408 0\n26 0.612227 0\n27 0.56844 0\n28 0.632306 0\n29 0.509829 0\n30 0.628823 0\n31 0.643104 0\n32 0.492681 0\n33 0.627534 0\n34 0.483608 0\n35 0.589605 0\n36 0.565321 0\n37 0.588392 0\n38 0.626599 0\n39 0.59092 0\n40 0.558518 0\n41 0.547117 0\n42 0.528735 0\n43 0.564053 0\n44 0.580688 0\n45 0.4797 0\n46 0.620292 0\n47 0.619275 0\n48 0.574393 0\n49 0.621845 0\n50 0.588598 0\n51 0.619111 0\n52 0.579864 0\n53 0.588229 0\n54 0.517787 0\n55 0.560814 0\n56 0.596994 0\n57 0.612762 0\n58 0.586818 0\n59 0.518596 0\n60 0.576993 0\n61 0.560525 0\n62 0.54628 0\n63 0.542241 0\n64 0.491675 0\n65 0
.615681 0\n209 0.511823 0\n210 0.52277 0\n211 0.488046 0\n212 0.529657 0\n213 0.534149 0\n214 0.512938 0\n215 0.544688 0\n216 0.571664 0\n217 0.514185 0\n218 0.522191 0\n219 0.513375 0\n220 0.524181 0\n221 0.50151 0\n222 0.5381 0\n223 0.567686 0\n224 0.551619 0\n225 0.590127 0\n226 0.62509 0\n227 0.509364 0\n228 0.505994 0\n229 0.589455 0\n230 0.621334 0\n231 0.567144 0\n232 0.531104 0\n233 0.619084 0\n234 0.549606 0\n235 0.57671 0\n236 0.486028 0\n237 0.503252 0\n238 0.583279 0\n239 0.51133 0\n240 0.678027 0\n241 0.629515 0\n242 0.553884 0\n243 0.580555 0\n244 0.53371 0\n245 0.529113 0\n246 0.606538 0\n247 0.603793 0\n248 0.612348 0\n249 0.565862 0\n250 0.603862 0\n251 0.603224 0\n252 0.588782 0\n253 0.612022 0\n254 0.48056 ...

# %%
biF = pd.read_csv("artificialData_basic_iForest.csv", delimiter=' ')
S0 = biF['Ascore'].to_numpy()

kiF = pd.read_csv("artificialData_kmeans_iForest.csv", delimiter=' ')
S1 = kiF['Ascore'].to_numpy()

# %% [markdown]
# ### Visualise Scores

# %%
ss0=np.argsort(S0)
ss1=np.argsort(S1)

x=data[:, 0]
y=data[:, 1]

f = plt.figure(figsize=(12,6))

ax1 = f.add_subplot(121)
ax1.scatter(x, y, s=1,c='b',edgecolor='b')
ax1.scatter(x[ss0[-20000:]],y[ss0[-20000:]],s=1,c='r')
plt.title("Basic iForest")

ax2 = f.add_subplot(122)
ax2.scatter(x, y, s=1,c='b',edgecolor='b')
ax2.scatter(x[ss1[-20000:]],y[ss1[-20000:]],s=1,c='r')
plt.title("Kmeans iForest")

plt.show()

# %%
ss0=np.argsort(S0)
ss1=np.argsort(S1)

x=data[:, 0]
y=data[:, 1]

f = plt.figure(figsize=(12,6))

ax1 = f.add_subplot(121)
ax1.scatter(x, y, s=1,c='b',edgecolor='b')
ax1.scatter(x[ss0[-100:]],y[ss0[-100:]],s=4,c='r')
plt.title("Basic iForest")

ax2 = f.add_subplot(122)
ax2.scatter(x, y, s=1,c='b',edgecolor='b')
ax2.scatter(x[ss1[-100:]],y[ss1[-100:]],s=4,c='r')
plt.title("Kmeans iForest")

plt.show()

# %%
ss0=np.argsort(S0)
ss1=np.argsort(S1)

x=data[:, 0]
y=data[:, 1]

f = plt.figure(figsize=(12,6))

ax1 = f.add_subplot(121)
ax1.scatter(x, y, s=1,c='b',edgecolor='b')
ax1.scatter(x[ss0[-1000:]],y[ss0[-1000:]],s=2,c='r')
plt.title("Basic iForest")

ax2 = f.add_subplot(122)
ax2.scatter(x, y, s=1,c='b',edgecolor='b')
ax2.scatter(x[ss1[-1000:]],y[ss1[-1000:]],s=2,c='r')
plt.title("Kmeans iForest")

plt.show()
